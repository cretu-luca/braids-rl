# %%
import sys
import os

# %%
import os
from src.config import Configuration
from src.braid_generator import BraidGenerator

# %%
n_strands = [3, 5, 7]
n_crossings = [8, 16, 24]
n_moves = [10, 50, 100]

samples_per_bed = 300

# %%
config = Configuration()

for st in n_strands:
    gen = BraidGenerator(n_strands=st, config=config)
    for cr in n_crossings:
        for mv in n_moves:
            filename = f"test_n{st}_c{cr}_m{mv}"
            full_path = os.path.join(config.DATA_DIR, f"{filename}.txt")
            gen.generate_dataset(samples_per_bed, cr, mv, full_path)
