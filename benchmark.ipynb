# %%
import argparse
import os
import pandas as pd
from typing import List
from stable_baselines3 import PPO
from src.config import Configuration
from src.braid_env import BraidEnv
from src.braid_agent import BraidAgent
from src.callbacks import BraidCallback

# %%
EXPERIMENTS = {
    1:  {"name": "Baseline_N3",   "train_n": [3], "test_n": [3]},
    2:  {"name": "Baseline_N5",   "train_n": [5], "test_n": [5]},
    3:  {"name": "Baseline_N7",   "train_n": [7], "test_n": [7]},
    
    4:  {"name": "Transfer_3to5", "train_n": [3], "test_n": [5]},
    5:  {"name": "Transfer_5to7", "train_n": [5], "test_n": [7]},
    
    6:  {"name": "Transfer_5to3", "train_n": [5], "test_n": [3]},
    7:  {"name": "Transfer_7to5", "train_n": [7], "test_n": [5]},
    
    8:  {"name": "Transfer_7to3", "train_n": [7], "test_n": [3]},
    
    9:  {"name": "Interpolation", "train_n": [3, 7],    "test_n": [5]},
    10: {"name": "Generalist",    "train_n": [3, 5, 7], "test_n": [3, 5, 7]},
    11: {"name": "OOD_N9",        "train_n": [3, 5, 7], "test_n": [9]}
}

# %%
def get_filenames(prefix, strands):
    files = []
    crossings = [8, 16, 24] 
    moves = [10, 50, 100]
    for n in strands:
        for c in crossings:
            for m in moves:
                files.append(f"{prefix}_n{n}_c{c}_m{m}.txt")
    return files

# %%
def train(agent: BraidAgent, n_strands: List[int], folder: str):
    print(f"\n--- Starting Training Phase ({folder}) ---")
    print(f"Strands: {n_strands}")
    
    prefix = "train" if folder == "train" else "ft"
    files = get_filenames(prefix, n_strands)
    
    total_budget = 300_000 
    if len(files) > 0:
        steps_per_file = int(total_budget / len(files))
        steps_per_file = max(steps_per_file, 5000)
    else:
        steps_per_file = 0
        print("Warning: No files found to train on.")

    is_finetuning = (folder == "finetune")

    for filename in files:
        full_path = os.path.join(agent.config.DATA_DIR, folder, f"{filename}")
        
        print(f">>> Training on {filename} ({steps_per_file} steps)...")
        try:
            env = BraidEnv(full_path, agent.config.N_STRANDS, agent.config.MAX_LEN, agent.config, finetune_mode=is_finetuning)

            callback = BraidCallback()
            
            log_label = f"{folder}_phase"
            
            agent.train(env, steps_per_file, agent.config.get_model_path(agent.name), callback=callback, log_name=log_label)

        except ValueError as e:
            print(f"    SKIPPING {filename}: {e}")
            continue
        except Exception as e:
             print(f"    ERROR on {filename}: {e}")
             continue

# %%
def test(agent: BraidAgent, n_strands: List[int]):
    print(f"\n--- Starting Testing Phase ---")
    print(f"Test Strands: {n_strands}")
    
    test_files = get_filenames("test", n_strands)

    exp_log_dir = os.path.join(agent.config.LOG_DIR, agent.name)
    
    agent.metrics.reset()
    total_success = 0
    total_episodes = 0
    results_table = []

    for filename in test_files:
        full_path = os.path.join(agent.config.DATA_DIR, "test", f"{filename}")
        print(f"Testing on {filename}...", end=" ")
        
        try:
            env_test = BraidEnv(full_path, agent.config.N_STRANDS, agent.config.MAX_LEN, agent.config)

            file_success = 0
            file_optimal = 0
            total_steps_taken = 0
            optimality_gap_sum = 0
            valid_gap_count = 0
            
            file_episodes = 20
            
            for _ in range(file_episodes):
                obs, _ = env_test.reset()
                
                optimal_steps = -1
                if hasattr(env_test.current_braid, 'optimal_steps'):
                    optimal_steps = env_test.current_braid.optimal_steps

                solved, steps = agent.solve(env_test, max_steps=200)
                
                if solved: 
                    file_success += 1
                    total_steps_taken += steps
                    
                    if optimal_steps > 0:
                        gap = steps - optimal_steps
                        optimality_gap_sum += gap
                        valid_gap_count += 1
                        
                        if gap == 0:
                            file_optimal += 1
            
            total_success += file_success
            total_episodes += file_episodes
            
            rate = (file_success/file_episodes)*100 if file_episodes > 0 else 0
            opt_rate = (file_optimal/file_episodes)*100 if file_episodes > 0 else 0
            
            avg_gap = optimality_gap_sum / valid_gap_count if valid_gap_count > 0 else -1
            gap_str = f"{avg_gap:.1f}" if avg_gap != -1 else "N/A"

            print(f"Score: {rate:.0f}% | Opt: {opt_rate:.0f}% | Gap: {gap_str}")
            
            results_table.append({
                "File": filename, 
                "Score": rate,
                "Optimal_Score": opt_rate,
                "Avg_Gap": avg_gap
            })
            
        except ValueError as e:
            print(f"FAILED to load: {e}")
        except Exception as e:
            print(f"ERROR: {e}")

    if results_table:
        df = pd.DataFrame(results_table)
        avg_score = df["Score"].mean()
        avg_opt = df["Optimal_Score"].mean()
        
        print(f"\n=== RESULTS: {agent.name} ===")
        print(f"Overall Success Rate: {avg_score:.2f}%")
        print(f"Overall Optimal Rate: {avg_opt:.2f}%")

        os.makedirs(exp_log_dir, exist_ok=True)
        csv_path = os.path.join(exp_log_dir, f"results_test.csv")
        df.to_csv(csv_path, index=False)
        print(f"Detailed results saved to {csv_path}")
    else:
        print("No results generated.")

# %%
def run_experiment(exp_id):
    if exp_id not in EXPERIMENTS:
        print(f"Experiment {exp_id} not found.")
        return

    exp = EXPERIMENTS[exp_id]
    print(f"\n{'='*60}")
    print(f"RUNNING EXPERIMENT {exp_id}: {exp['name']}")
    print(f"Train Strands: {exp['train_n']} -> Test Strands: {exp['test_n']}")
    print(f"{'='*60}")

    max_strands_needed = max(exp['train_n'] + exp['test_n'])
    
    config = Configuration(
        n_strands=max_strands_needed, 
        max_len=100,
        total_timesteps=300_000,
        learning_rate=0.0003
    )

    agent_name = f"Exp{exp_id}_{exp['name']}_pretrained"
    
    exp_log_dir = os.path.join(config.LOG_DIR, f"Exp_{exp_id}_{exp['name']}")
    
    hyperparams = {
        "learning_rate": config.LEARNING_RATE,
        "ent_coef": config.ENTROPY_COEF,
        "tensorboard_log": exp_log_dir
    }

    agent = BraidAgent(config, hyperparams, name=agent_name)
    train(agent, exp['train_n'], folder="train")
    
    print("\n>>> Testing Pre-Trained Model...")
    test(agent, exp['test_n'])

    agent.name = f"Exp{exp_id}_{exp['name']}_finetuned"
    
    print(f"\n>>> Switching to Fine-Tuning Mode (New Model Name: {agent.name})")
    
    train(agent, exp['train_n'], folder="finetune")
    
    print("\n>>> Testing Fine-Tuned Model...")
    test(agent, exp['test_n'])

    print(f"\nExperiment {exp_id} Complete.")

# %%
for i in range(1, 11):
    run_experiment(i)
# Out:
# ============================================================
# RUNNING EXPERIMENT 1: Baseline_N3
# Train Strands: [3] -> Test Strands: [3]
# ============================================================
#
# --- Starting Training Phase (train) ---
# Strands: [3]
# >>> Training on train_n3_c8_m10.txt (33333 steps)...
# [Exp1_Baseline_N3_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c8_m50.txt (33333 steps)...
# [Exp1_Baseline_N3_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c8_m100.txt (33333 steps)...
# [Exp1_Baseline_N3_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c16_m10.txt (33333 steps)...
# [Exp1_Baseline_N3_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c16_m50.txt (33333 steps)...
# [Exp1_Baseline_N3_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c16_m100.txt (33333 steps)...
# [Exp1_Baseline_N3_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c24_m10.txt (33333 steps)...
# [Exp1_Baseline_N3_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c24_m50.txt (33333 steps)...
# [Exp1_Baseline_N3_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c24_m100.txt (33333 steps)...
# [Exp1_Baseline_N3_pretrained] Training for 33333 steps...
#
# >>> Testing Pre-Trained Model...
#
# --- Starting Testing Phase ---
# Test Strands: [3]
# Testing on test_n3_c8_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m100.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m100.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c24_m10.txt... Score: 90% | Opt: 80% | Gap: 0.0
# Testing on test_n3_c24_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c24_m100.txt... Score: 95% | Opt: 90% | Gap: 0.1
#
# === RESULTS: Exp1_Baseline_N3_pretrained ===
# Overall Success Rate: 98.33%
# Overall Optimal Rate: 96.67%
# Detailed results saved to ./logs/Exp1_Baseline_N3_pretrained/results_test.csv
#
# >>> Switching to Fine-Tuning Mode (New Model Name: Exp1_Baseline_N3_finetuned)
#
# --- Starting Training Phase (finetune) ---
# Strands: [3]
# >>> Training on ft_n3_c8_m10.txt (33333 steps)...
# [Exp1_Baseline_N3_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c8_m50.txt (33333 steps)...
# [Exp1_Baseline_N3_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c8_m100.txt (33333 steps)...
# [Exp1_Baseline_N3_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c16_m10.txt (33333 steps)...
# [Exp1_Baseline_N3_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c16_m50.txt (33333 steps)...
# [Exp1_Baseline_N3_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c16_m100.txt (33333 steps)...
# [Exp1_Baseline_N3_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c24_m10.txt (33333 steps)...
# [Exp1_Baseline_N3_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c24_m50.txt (33333 steps)...
# [Exp1_Baseline_N3_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c24_m100.txt (33333 steps)...
# [Exp1_Baseline_N3_finetuned] Training for 33333 steps...
#
# >>> Testing Fine-Tuned Model...
#
# --- Starting Testing Phase ---
# Test Strands: [3]
# Testing on test_n3_c8_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m100.txt... Score: 100% | Opt: 95% | Gap: 0.1
# Testing on test_n3_c16_m10.txt... Score: 100% | Opt: 95% | Gap: 0.1
# Testing on test_n3_c16_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m100.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c24_m10.txt... Score: 100% | Opt: 95% | Gap: -0.1
# Testing on test_n3_c24_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c24_m100.txt... Score: 100% | Opt: 85% | Gap: -0.1
#
# === RESULTS: Exp1_Baseline_N3_finetuned ===
# Overall Success Rate: 100.00%
# Overall Optimal Rate: 96.67%
# Detailed results saved to ./logs/Exp1_Baseline_N3_finetuned/results_test.csv
#
# Experiment 1 Complete.
#
# ============================================================
# RUNNING EXPERIMENT 2: Baseline_N5
# Train Strands: [5] -> Test Strands: [5]
# ============================================================
#
# --- Starting Training Phase (train) ---
# Strands: [5]
# >>> Training on train_n5_c8_m10.txt (33333 steps)...
# [Exp2_Baseline_N5_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c8_m50.txt (33333 steps)...
# [Exp2_Baseline_N5_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c8_m100.txt (33333 steps)...
# [Exp2_Baseline_N5_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c16_m10.txt (33333 steps)...
# [Exp2_Baseline_N5_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c16_m50.txt (33333 steps)...
# [Exp2_Baseline_N5_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c16_m100.txt (33333 steps)...
# [Exp2_Baseline_N5_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c24_m10.txt (33333 steps)...
# [Exp2_Baseline_N5_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c24_m50.txt (33333 steps)...
# [Exp2_Baseline_N5_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c24_m100.txt (33333 steps)...
# [Exp2_Baseline_N5_pretrained] Training for 33333 steps...
#
# >>> Testing Pre-Trained Model...
#
# --- Starting Testing Phase ---
# Test Strands: [5]
# Testing on test_n5_c8_m10.txt... Score: 100% | Opt: 55% | Gap: 0.1
# Testing on test_n5_c8_m50.txt... Score: 100% | Opt: 75% | Gap: 0.1
# Testing on test_n5_c8_m100.txt... Score: 100% | Opt: 70% | Gap: -0.2
# Testing on test_n5_c16_m10.txt... Score: 100% | Opt: 60% | Gap: 0.2
# Testing on test_n5_c16_m50.txt... Score: 100% | Opt: 25% | Gap: -0.6
# Testing on test_n5_c16_m100.txt... Score: 95% | Opt: 40% | Gap: -0.4
# Testing on test_n5_c24_m10.txt... Score: 100% | Opt: 50% | Gap: 0.1
# Testing on test_n5_c24_m50.txt... Score: 95% | Opt: 40% | Gap: 0.2
# Testing on test_n5_c24_m100.txt... Score: 100% | Opt: 20% | Gap: 0.7
#
# === RESULTS: Exp2_Baseline_N5_pretrained ===
# Overall Success Rate: 98.89%
# Overall Optimal Rate: 48.33%
# Detailed results saved to ./logs/Exp2_Baseline_N5_pretrained/results_test.csv
#
# >>> Switching to Fine-Tuning Mode (New Model Name: Exp2_Baseline_N5_finetuned)
#
# --- Starting Training Phase (finetune) ---
# Strands: [5]
# >>> Training on ft_n5_c8_m10.txt (33333 steps)...
# [Exp2_Baseline_N5_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c8_m50.txt (33333 steps)...
# [Exp2_Baseline_N5_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c8_m100.txt (33333 steps)...
# [Exp2_Baseline_N5_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c16_m10.txt (33333 steps)...
# [Exp2_Baseline_N5_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c16_m50.txt (33333 steps)...
# [Exp2_Baseline_N5_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c16_m100.txt (33333 steps)...
# [Exp2_Baseline_N5_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c24_m10.txt (33333 steps)...
# [Exp2_Baseline_N5_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c24_m50.txt (33333 steps)...
# [Exp2_Baseline_N5_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c24_m100.txt (33333 steps)...
# [Exp2_Baseline_N5_finetuned] Training for 33333 steps...
#
# >>> Testing Fine-Tuned Model...
#
# --- Starting Testing Phase ---
# Test Strands: [5]
# Testing on test_n5_c8_m10.txt... Score: 100% | Opt: 70% | Gap: -0.2
# Testing on test_n5_c8_m50.txt... Score: 100% | Opt: 75% | Gap: 0.5
# Testing on test_n5_c8_m100.txt... Score: 100% | Opt: 55% | Gap: 0.4
# Testing on test_n5_c16_m10.txt... Score: 100% | Opt: 50% | Gap: 0.2
# Testing on test_n5_c16_m50.txt... Score: 100% | Opt: 50% | Gap: -0.2
# Testing on test_n5_c16_m100.txt... Score: 95% | Opt: 25% | Gap: -0.1
# Testing on test_n5_c24_m10.txt... Score: 100% | Opt: 55% | Gap: 0.2
# Testing on test_n5_c24_m50.txt... Score: 100% | Opt: 45% | Gap: -0.7
# Testing on test_n5_c24_m100.txt... Score: 100% | Opt: 50% | Gap: 0.1
#
# === RESULTS: Exp2_Baseline_N5_finetuned ===
# Overall Success Rate: 99.44%
# Overall Optimal Rate: 52.78%
# Detailed results saved to ./logs/Exp2_Baseline_N5_finetuned/results_test.csv
#
# Experiment 2 Complete.
#
# ============================================================
# RUNNING EXPERIMENT 3: Baseline_N7
# Train Strands: [7] -> Test Strands: [7]
# ============================================================
#
# --- Starting Training Phase (train) ---
# Strands: [7]
# >>> Training on train_n7_c8_m10.txt (33333 steps)...
# [Exp3_Baseline_N7_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c8_m50.txt (33333 steps)...
# [Exp3_Baseline_N7_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c8_m100.txt (33333 steps)...
# [Exp3_Baseline_N7_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c16_m10.txt (33333 steps)...
# [Exp3_Baseline_N7_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c16_m50.txt (33333 steps)...
# [Exp3_Baseline_N7_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c16_m100.txt (33333 steps)...
# [Exp3_Baseline_N7_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c24_m10.txt (33333 steps)...
# [Exp3_Baseline_N7_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c24_m50.txt (33333 steps)...
# [Exp3_Baseline_N7_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c24_m100.txt (33333 steps)...
# [Exp3_Baseline_N7_pretrained] Training for 33333 steps...
#
# >>> Testing Pre-Trained Model...
#
# --- Starting Testing Phase ---
# Test Strands: [7]
# Testing on test_n7_c8_m10.txt... Score: 70% | Opt: 55% | Gap: 0.1
# Testing on test_n7_c8_m50.txt... Score: 75% | Opt: 30% | Gap: 0.5
# Testing on test_n7_c8_m100.txt... Score: 60% | Opt: 30% | Gap: 2.8
# Testing on test_n7_c16_m10.txt... Score: 55% | Opt: 30% | Gap: 0.9
# Testing on test_n7_c16_m50.txt... Score: 30% | Opt: 10% | Gap: 2.5
# Testing on test_n7_c16_m100.txt... Score: 20% | Opt: 5% | Gap: N/A
# Testing on test_n7_c24_m10.txt... Score: 25% | Opt: 5% | Gap: 1.2
# Testing on test_n7_c24_m50.txt... Score: 10% | Opt: 5% | Gap: 0.0
# Testing on test_n7_c24_m100.txt... Score: 20% | Opt: 5% | Gap: 2.7
#
# === RESULTS: Exp3_Baseline_N7_pretrained ===
# Overall Success Rate: 40.56%
# Overall Optimal Rate: 19.44%
# Detailed results saved to ./logs/Exp3_Baseline_N7_pretrained/results_test.csv
#
# >>> Switching to Fine-Tuning Mode (New Model Name: Exp3_Baseline_N7_finetuned)
#
# --- Starting Training Phase (finetune) ---
# Strands: [7]
# >>> Training on ft_n7_c8_m10.txt (33333 steps)...
# [Exp3_Baseline_N7_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c8_m50.txt (33333 steps)...
# [Exp3_Baseline_N7_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c8_m100.txt (33333 steps)...
# [Exp3_Baseline_N7_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c16_m10.txt (33333 steps)...
# [Exp3_Baseline_N7_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c16_m50.txt (33333 steps)...
# [Exp3_Baseline_N7_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c16_m100.txt (33333 steps)...
# [Exp3_Baseline_N7_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c24_m10.txt (33333 steps)...
# [Exp3_Baseline_N7_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c24_m50.txt (33333 steps)...
# [Exp3_Baseline_N7_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c24_m100.txt (33333 steps)...
# [Exp3_Baseline_N7_finetuned] Training for 33333 steps...
#
# >>> Testing Fine-Tuned Model...
#
# --- Starting Testing Phase ---
# Test Strands: [7]
# Testing on test_n7_c8_m10.txt... Score: 100% | Opt: 70% | Gap: 0.0
# Testing on test_n7_c8_m50.txt... Score: 100% | Opt: 70% | Gap: 0.2
# Testing on test_n7_c8_m100.txt... Score: 100% | Opt: 50% | Gap: 0.5
# Testing on test_n7_c16_m10.txt... Score: 100% | Opt: 50% | Gap: 0.0
# Testing on test_n7_c16_m50.txt... Score: 95% | Opt: 35% | Gap: 0.7
# Testing on test_n7_c16_m100.txt... Score: 100% | Opt: 45% | Gap: 0.3
# Testing on test_n7_c24_m10.txt... Score: 100% | Opt: 20% | Gap: 0.7
# Testing on test_n7_c24_m50.txt... Score: 95% | Opt: 30% | Gap: 1.0
# Testing on test_n7_c24_m100.txt... Score: 85% | Opt: 5% | Gap: 2.8
#
# === RESULTS: Exp3_Baseline_N7_finetuned ===
# Overall Success Rate: 97.22%
# Overall Optimal Rate: 41.67%
# Detailed results saved to ./logs/Exp3_Baseline_N7_finetuned/results_test.csv
#
# Experiment 3 Complete.
#
# ============================================================
# RUNNING EXPERIMENT 4: Transfer_3to5
# Train Strands: [3] -> Test Strands: [5]
# ============================================================
#
# --- Starting Training Phase (train) ---
# Strands: [3]
# >>> Training on train_n3_c8_m10.txt (33333 steps)...
# [Exp4_Transfer_3to5_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c8_m50.txt (33333 steps)...
# [Exp4_Transfer_3to5_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c8_m100.txt (33333 steps)...
# [Exp4_Transfer_3to5_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c16_m10.txt (33333 steps)...
# [Exp4_Transfer_3to5_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c16_m50.txt (33333 steps)...
# [Exp4_Transfer_3to5_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c16_m100.txt (33333 steps)...
# [Exp4_Transfer_3to5_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c24_m10.txt (33333 steps)...
# [Exp4_Transfer_3to5_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c24_m50.txt (33333 steps)...
# [Exp4_Transfer_3to5_pretrained] Training for 33333 steps...
# >>> Training on train_n3_c24_m100.txt (33333 steps)...
# [Exp4_Transfer_3to5_pretrained] Training for 33333 steps...
#
# >>> Testing Pre-Trained Model...
#
# --- Starting Testing Phase ---
# Test Strands: [5]
# Testing on test_n5_c8_m10.txt... Score: 95% | Opt: 80% | Gap: -0.1
# Testing on test_n5_c8_m50.txt... Score: 100% | Opt: 85% | Gap: -0.1
# Testing on test_n5_c8_m100.txt... Score: 100% | Opt: 60% | Gap: -0.4
# Testing on test_n5_c16_m10.txt... Score: 70% | Opt: 40% | Gap: -0.3
# Testing on test_n5_c16_m50.txt... Score: 65% | Opt: 25% | Gap: 0.3
# Testing on test_n5_c16_m100.txt... Score: 65% | Opt: 25% | Gap: -0.6
# Testing on test_n5_c24_m10.txt... Score: 80% | Opt: 20% | Gap: 0.1
# Testing on test_n5_c24_m50.txt... Score: 45% | Opt: 10% | Gap: 0.5
# Testing on test_n5_c24_m100.txt... Score: 60% | Opt: 40% | Gap: 0.3
#
# === RESULTS: Exp4_Transfer_3to5_pretrained ===
# Overall Success Rate: 75.56%
# Overall Optimal Rate: 42.78%
# Detailed results saved to ./logs/Exp4_Transfer_3to5_pretrained/results_test.csv
#
# >>> Switching to Fine-Tuning Mode (New Model Name: Exp4_Transfer_3to5_finetuned)
#
# --- Starting Training Phase (finetune) ---
# Strands: [3]
# >>> Training on ft_n3_c8_m10.txt (33333 steps)...
# [Exp4_Transfer_3to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c8_m50.txt (33333 steps)...
# [Exp4_Transfer_3to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c8_m100.txt (33333 steps)...
# [Exp4_Transfer_3to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c16_m10.txt (33333 steps)...
# [Exp4_Transfer_3to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c16_m50.txt (33333 steps)...
# [Exp4_Transfer_3to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c16_m100.txt (33333 steps)...
# [Exp4_Transfer_3to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c24_m10.txt (33333 steps)...
# [Exp4_Transfer_3to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c24_m50.txt (33333 steps)...
# [Exp4_Transfer_3to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n3_c24_m100.txt (33333 steps)...
# [Exp4_Transfer_3to5_finetuned] Training for 33333 steps...
#
# >>> Testing Fine-Tuned Model...
#
# --- Starting Testing Phase ---
# Test Strands: [5]
# Testing on test_n5_c8_m10.txt... Score: 40% | Opt: 40% | Gap: 0.0
# Testing on test_n5_c8_m50.txt... Score: 50% | Opt: 40% | Gap: -0.4
# Testing on test_n5_c8_m100.txt... Score: 70% | Opt: 45% | Gap: -0.1
# Testing on test_n5_c16_m10.txt... Score: 10% | Opt: 10% | Gap: 0.0
# Testing on test_n5_c16_m50.txt... Score: 30% | Opt: 25% | Gap: -0.3
# Testing on test_n5_c16_m100.txt... Score: 10% | Opt: 0% | Gap: -2.0
# Testing on test_n5_c24_m10.txt... Score: 5% | Opt: 0% | Gap: -2.0
# Testing on test_n5_c24_m50.txt... Score: 5% | Opt: 0% | Gap: 2.0
# Testing on test_n5_c24_m100.txt... Score: 0% | Opt: 0% | Gap: N/A
#
# === RESULTS: Exp4_Transfer_3to5_finetuned ===
# Overall Success Rate: 24.44%
# Overall Optimal Rate: 17.78%
# Detailed results saved to ./logs/Exp4_Transfer_3to5_finetuned/results_test.csv
#
# Experiment 4 Complete.
#
# ============================================================
# RUNNING EXPERIMENT 5: Transfer_5to7
# Train Strands: [5] -> Test Strands: [7]
# ============================================================
#
# --- Starting Training Phase (train) ---
# Strands: [5]
# >>> Training on train_n5_c8_m10.txt (33333 steps)...
# [Exp5_Transfer_5to7_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c8_m50.txt (33333 steps)...
# [Exp5_Transfer_5to7_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c8_m100.txt (33333 steps)...
# [Exp5_Transfer_5to7_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c16_m10.txt (33333 steps)...
# [Exp5_Transfer_5to7_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c16_m50.txt (33333 steps)...
# [Exp5_Transfer_5to7_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c16_m100.txt (33333 steps)...
# [Exp5_Transfer_5to7_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c24_m10.txt (33333 steps)...
# [Exp5_Transfer_5to7_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c24_m50.txt (33333 steps)...
# [Exp5_Transfer_5to7_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c24_m100.txt (33333 steps)...
# [Exp5_Transfer_5to7_pretrained] Training for 33333 steps...
#
# >>> Testing Pre-Trained Model...
#
# --- Starting Testing Phase ---
# Test Strands: [7]
# Testing on test_n7_c8_m10.txt... Score: 75% | Opt: 40% | Gap: 0.7
# Testing on test_n7_c8_m50.txt... Score: 55% | Opt: 40% | Gap: 0.2
# Testing on test_n7_c8_m100.txt... Score: 70% | Opt: 20% | Gap: 2.1
# Testing on test_n7_c16_m10.txt... Score: 40% | Opt: 0% | Gap: 10.9
# Testing on test_n7_c16_m50.txt... Score: 15% | Opt: 5% | Gap: 9.0
# Testing on test_n7_c16_m100.txt... Score: 15% | Opt: 0% | Gap: 7.0
# Testing on test_n7_c24_m10.txt... Score: 15% | Opt: 0% | Gap: 7.0
# Testing on test_n7_c24_m50.txt... Score: 5% | Opt: 0% | Gap: N/A
# Testing on test_n7_c24_m100.txt... Score: 5% | Opt: 0% | Gap: 4.0
#
# === RESULTS: Exp5_Transfer_5to7_pretrained ===
# Overall Success Rate: 32.78%
# Overall Optimal Rate: 11.67%
# Detailed results saved to ./logs/Exp5_Transfer_5to7_pretrained/results_test.csv
#
# >>> Switching to Fine-Tuning Mode (New Model Name: Exp5_Transfer_5to7_finetuned)
#
# --- Starting Training Phase (finetune) ---
# Strands: [5]
# >>> Training on ft_n5_c8_m10.txt (33333 steps)...
# [Exp5_Transfer_5to7_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c8_m50.txt (33333 steps)...
# [Exp5_Transfer_5to7_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c8_m100.txt (33333 steps)...
# [Exp5_Transfer_5to7_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c16_m10.txt (33333 steps)...
# [Exp5_Transfer_5to7_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c16_m50.txt (33333 steps)...
# [Exp5_Transfer_5to7_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c16_m100.txt (33333 steps)...
# [Exp5_Transfer_5to7_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c24_m10.txt (33333 steps)...
# [Exp5_Transfer_5to7_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c24_m50.txt (33333 steps)...
# [Exp5_Transfer_5to7_finetuned] Training for 33333 steps...
#     SKIPPING ft_n5_c24_m50.txt: Expected parameter probs (Tensor of shape (64, 400)) of distribution MaskableCategorical(probs: torch.Size([64, 400]), logits: torch.Size([64, 400])) to satisfy the constraint Simplex(), but found invalid values:
# tensor([[3.3856e-05, 4.0197e-05, 2.0259e-03,  ..., 1.4393e-04, 1.4393e-04,
#          1.4409e-04],
#         [1.7159e-03, 7.7613e-04, 3.0011e-04,  ..., 7.1923e-04, 7.1715e-04,
#          7.1571e-04],
#         [1.4804e-06, 3.3549e-05, 2.4431e-04,  ..., 4.5725e-05, 4.5720e-05,
#          4.5728e-05],
#         ...,
#         [2.3230e-04, 1.5457e-04, 1.8419e-05,  ..., 1.0728e-04, 1.0719e-04,
#          1.0727e-04],
#         [5.4092e-06, 5.4551e-06, 4.1183e-05,  ..., 3.6346e-05, 3.6147e-05,
#          3.6116e-05],
#         [1.7059e-05, 3.3110e-04, 5.6327e-04,  ..., 8.2223e-05, 8.1953e-05,
#          8.1997e-05]], grad_fn=<SoftmaxBackward0>)
# >>> Training on ft_n5_c24_m100.txt (33333 steps)...
# [Exp5_Transfer_5to7_finetuned] Training for 33333 steps...
#
# >>> Testing Fine-Tuned Model...
#
# --- Starting Testing Phase ---
# Test Strands: [7]
# Testing on test_n7_c8_m10.txt... Score: 100% | Opt: 50% | Gap: 0.0
# Testing on test_n7_c8_m50.txt... Score: 100% | Opt: 70% | Gap: 0.4
# Testing on test_n7_c8_m100.txt... Score: 100% | Opt: 75% | Gap: -0.1
# Testing on test_n7_c16_m10.txt... Score: 95% | Opt: 60% | Gap: -0.5
# Testing on test_n7_c16_m50.txt... Score: 100% | Opt: 60% | Gap: 0.3
# Testing on test_n7_c16_m100.txt... Score: 95% | Opt: 20% | Gap: 1.1
# Testing on test_n7_c24_m10.txt... Score: 90% | Opt: 15% | Gap: 0.4
# Testing on test_n7_c24_m50.txt... Score: 95% | Opt: 45% | Gap: 0.5
# Testing on test_n7_c24_m100.txt... Score: 85% | Opt: 15% | Gap: 0.6
#
# === RESULTS: Exp5_Transfer_5to7_finetuned ===
# Overall Success Rate: 95.56%
# Overall Optimal Rate: 45.56%
# Detailed results saved to ./logs/Exp5_Transfer_5to7_finetuned/results_test.csv
#
# Experiment 5 Complete.
#
# ============================================================
# RUNNING EXPERIMENT 6: Transfer_5to3
# Train Strands: [5] -> Test Strands: [3]
# ============================================================
#
# --- Starting Training Phase (train) ---
# Strands: [5]
# >>> Training on train_n5_c8_m10.txt (33333 steps)...
# [Exp6_Transfer_5to3_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c8_m50.txt (33333 steps)...
# [Exp6_Transfer_5to3_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c8_m100.txt (33333 steps)...
# [Exp6_Transfer_5to3_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c16_m10.txt (33333 steps)...
# [Exp6_Transfer_5to3_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c16_m50.txt (33333 steps)...
# [Exp6_Transfer_5to3_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c16_m100.txt (33333 steps)...
# [Exp6_Transfer_5to3_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c24_m10.txt (33333 steps)...
# [Exp6_Transfer_5to3_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c24_m50.txt (33333 steps)...
# [Exp6_Transfer_5to3_pretrained] Training for 33333 steps...
# >>> Training on train_n5_c24_m100.txt (33333 steps)...
# [Exp6_Transfer_5to3_pretrained] Training for 33333 steps...
#
# >>> Testing Pre-Trained Model...
#
# --- Starting Testing Phase ---
# Test Strands: [3]
# Testing on test_n3_c8_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m100.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m100.txt... Score: 100% | Opt: 95% | Gap: 0.1
# Testing on test_n3_c24_m10.txt... Score: 100% | Opt: 95% | Gap: -0.1
# Testing on test_n3_c24_m50.txt... Score: 95% | Opt: 95% | Gap: 0.0
# Testing on test_n3_c24_m100.txt... Score: 100% | Opt: 85% | Gap: -0.1
#
# === RESULTS: Exp6_Transfer_5to3_pretrained ===
# Overall Success Rate: 99.44%
# Overall Optimal Rate: 96.67%
# Detailed results saved to ./logs/Exp6_Transfer_5to3_pretrained/results_test.csv
#
# >>> Switching to Fine-Tuning Mode (New Model Name: Exp6_Transfer_5to3_finetuned)
#
# --- Starting Training Phase (finetune) ---
# Strands: [5]
# >>> Training on ft_n5_c8_m10.txt (33333 steps)...
# [Exp6_Transfer_5to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c8_m50.txt (33333 steps)...
# [Exp6_Transfer_5to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c8_m100.txt (33333 steps)...
# [Exp6_Transfer_5to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c16_m10.txt (33333 steps)...
# [Exp6_Transfer_5to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c16_m50.txt (33333 steps)...
# [Exp6_Transfer_5to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c16_m100.txt (33333 steps)...
# [Exp6_Transfer_5to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c24_m10.txt (33333 steps)...
# [Exp6_Transfer_5to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c24_m50.txt (33333 steps)...
# [Exp6_Transfer_5to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n5_c24_m100.txt (33333 steps)...
# [Exp6_Transfer_5to3_finetuned] Training for 33333 steps...
#     SKIPPING ft_n5_c24_m100.txt: Expected parameter probs (Tensor of shape (64, 400)) of distribution MaskableCategorical(probs: torch.Size([64, 400]), logits: torch.Size([64, 400])) to satisfy the constraint Simplex(), but found invalid values:
# tensor([[2.1210e-04, 3.0692e-03, 8.0082e-05,  ..., 1.5756e-04, 1.5687e-04,
#          1.5590e-04],
#         [1.9270e-06, 2.7739e-06, 4.5242e-06,  ..., 5.1223e-05, 5.0970e-05,
#          5.0732e-05],
#         [8.0978e-06, 1.7494e-05, 6.2562e-06,  ..., 1.2896e-04, 1.2898e-04,
#          1.2792e-04],
#         ...,
#         [7.2908e-05, 1.2964e-04, 1.0194e-03,  ..., 9.4238e-05, 9.3722e-05,
#          9.3160e-05],
#         [2.3640e-04, 5.9678e-04, 2.5312e-05,  ..., 1.2643e-04, 1.2611e-04,
#          1.2520e-04],
#         [2.2773e-06, 8.8526e-06, 3.9857e-06,  ..., 5.8356e-05, 5.8281e-05,
#          5.7928e-05]], grad_fn=<SoftmaxBackward0>)
#
# >>> Testing Fine-Tuned Model...
#
# --- Starting Testing Phase ---
# Test Strands: [3]
# Testing on test_n3_c8_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m100.txt... Score: 100% | Opt: 95% | Gap: 0.1
# Testing on test_n3_c16_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m100.txt... Score: 100% | Opt: 95% | Gap: -0.1
# Testing on test_n3_c24_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c24_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c24_m100.txt... Score: 95% | Opt: 90% | Gap: -0.1
#
# === RESULTS: Exp6_Transfer_5to3_finetuned ===
# Overall Success Rate: 99.44%
# Overall Optimal Rate: 97.78%
# Detailed results saved to ./logs/Exp6_Transfer_5to3_finetuned/results_test.csv
#
# Experiment 6 Complete.
#
# ============================================================
# RUNNING EXPERIMENT 7: Transfer_7to5
# Train Strands: [7] -> Test Strands: [5]
# ============================================================
#
# --- Starting Training Phase (train) ---
# Strands: [7]
# >>> Training on train_n7_c8_m10.txt (33333 steps)...
# [Exp7_Transfer_7to5_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c8_m50.txt (33333 steps)...
# [Exp7_Transfer_7to5_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c8_m100.txt (33333 steps)...
# [Exp7_Transfer_7to5_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c16_m10.txt (33333 steps)...
# [Exp7_Transfer_7to5_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c16_m50.txt (33333 steps)...
# [Exp7_Transfer_7to5_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c16_m100.txt (33333 steps)...
# [Exp7_Transfer_7to5_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c24_m10.txt (33333 steps)...
# [Exp7_Transfer_7to5_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c24_m50.txt (33333 steps)...
# [Exp7_Transfer_7to5_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c24_m100.txt (33333 steps)...
# [Exp7_Transfer_7to5_pretrained] Training for 33333 steps...
#
# >>> Testing Pre-Trained Model...
#
# --- Starting Testing Phase ---
# Test Strands: [5]
# Testing on test_n5_c8_m10.txt... Score: 90% | Opt: 50% | Gap: 1.8
# Testing on test_n5_c8_m50.txt... Score: 80% | Opt: 70% | Gap: 0.0
# Testing on test_n5_c8_m100.txt... Score: 90% | Opt: 60% | Gap: 0.1
# Testing on test_n5_c16_m10.txt... Score: 20% | Opt: 10% | Gap: 2.0
# Testing on test_n5_c16_m50.txt... Score: 40% | Opt: 5% | Gap: 4.0
# Testing on test_n5_c16_m100.txt... Score: 30% | Opt: 10% | Gap: 9.0
# Testing on test_n5_c24_m10.txt... Score: 25% | Opt: 10% | Gap: 0.8
# Testing on test_n5_c24_m50.txt... Score: 5% | Opt: 0% | Gap: 4.0
# Testing on test_n5_c24_m100.txt... Score: 10% | Opt: 0% | Gap: 5.0
#
# === RESULTS: Exp7_Transfer_7to5_pretrained ===
# Overall Success Rate: 43.33%
# Overall Optimal Rate: 23.89%
# Detailed results saved to ./logs/Exp7_Transfer_7to5_pretrained/results_test.csv
#
# >>> Switching to Fine-Tuning Mode (New Model Name: Exp7_Transfer_7to5_finetuned)
#
# --- Starting Training Phase (finetune) ---
# Strands: [7]
# >>> Training on ft_n7_c8_m10.txt (33333 steps)...
# [Exp7_Transfer_7to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c8_m50.txt (33333 steps)...
# [Exp7_Transfer_7to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c8_m100.txt (33333 steps)...
# [Exp7_Transfer_7to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c16_m10.txt (33333 steps)...
# [Exp7_Transfer_7to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c16_m50.txt (33333 steps)...
# [Exp7_Transfer_7to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c16_m100.txt (33333 steps)...
# [Exp7_Transfer_7to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c24_m10.txt (33333 steps)...
# [Exp7_Transfer_7to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c24_m50.txt (33333 steps)...
# [Exp7_Transfer_7to5_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c24_m100.txt (33333 steps)...
# [Exp7_Transfer_7to5_finetuned] Training for 33333 steps...
#
# >>> Testing Fine-Tuned Model...
#
# --- Starting Testing Phase ---
# Test Strands: [5]
# Testing on test_n5_c8_m10.txt... Score: 100% | Opt: 70% | Gap: 0.0
# Testing on test_n5_c8_m50.txt... Score: 100% | Opt: 90% | Gap: 0.0
# Testing on test_n5_c8_m100.txt... Score: 100% | Opt: 80% | Gap: 0.2
# Testing on test_n5_c16_m10.txt... Score: 100% | Opt: 40% | Gap: 0.2
# Testing on test_n5_c16_m50.txt... Score: 100% | Opt: 50% | Gap: -0.2
# Testing on test_n5_c16_m100.txt... Score: 100% | Opt: 50% | Gap: 0.0
# Testing on test_n5_c24_m10.txt... Score: 90% | Opt: 25% | Gap: -0.2
# Testing on test_n5_c24_m50.txt... Score: 100% | Opt: 50% | Gap: 0.6
# Testing on test_n5_c24_m100.txt... Score: 100% | Opt: 70% | Gap: 0.1
#
# === RESULTS: Exp7_Transfer_7to5_finetuned ===
# Overall Success Rate: 98.89%
# Overall Optimal Rate: 58.33%
# Detailed results saved to ./logs/Exp7_Transfer_7to5_finetuned/results_test.csv
#
# Experiment 7 Complete.
#
# ============================================================
# RUNNING EXPERIMENT 8: Transfer_7to3
# Train Strands: [7] -> Test Strands: [3]
# ============================================================
#
# --- Starting Training Phase (train) ---
# Strands: [7]
# >>> Training on train_n7_c8_m10.txt (33333 steps)...
# [Exp8_Transfer_7to3_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c8_m50.txt (33333 steps)...
# [Exp8_Transfer_7to3_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c8_m100.txt (33333 steps)...
# [Exp8_Transfer_7to3_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c16_m10.txt (33333 steps)...
# [Exp8_Transfer_7to3_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c16_m50.txt (33333 steps)...
# [Exp8_Transfer_7to3_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c16_m100.txt (33333 steps)...
# [Exp8_Transfer_7to3_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c24_m10.txt (33333 steps)...
# [Exp8_Transfer_7to3_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c24_m50.txt (33333 steps)...
# [Exp8_Transfer_7to3_pretrained] Training for 33333 steps...
# >>> Training on train_n7_c24_m100.txt (33333 steps)...
# [Exp8_Transfer_7to3_pretrained] Training for 33333 steps...
#
# >>> Testing Pre-Trained Model...
#
# --- Starting Testing Phase ---
# Test Strands: [3]
# Testing on test_n3_c8_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m100.txt... Score: 95% | Opt: 85% | Gap: 0.2
# Testing on test_n3_c16_m10.txt... Score: 100% | Opt: 80% | Gap: 0.5
# Testing on test_n3_c16_m50.txt... Score: 100% | Opt: 90% | Gap: 0.2
# Testing on test_n3_c16_m100.txt... Score: 100% | Opt: 95% | Gap: 0.1
# Testing on test_n3_c24_m10.txt... Score: 95% | Opt: 85% | Gap: 0.4
# Testing on test_n3_c24_m50.txt... Score: 90% | Opt: 75% | Gap: 0.8
# Testing on test_n3_c24_m100.txt... Score: 95% | Opt: 70% | Gap: 0.9
#
# === RESULTS: Exp8_Transfer_7to3_pretrained ===
# Overall Success Rate: 97.22%
# Overall Optimal Rate: 86.67%
# Detailed results saved to ./logs/Exp8_Transfer_7to3_pretrained/results_test.csv
#
# >>> Switching to Fine-Tuning Mode (New Model Name: Exp8_Transfer_7to3_finetuned)
#
# --- Starting Training Phase (finetune) ---
# Strands: [7]
# >>> Training on ft_n7_c8_m10.txt (33333 steps)...
# [Exp8_Transfer_7to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c8_m50.txt (33333 steps)...
# [Exp8_Transfer_7to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c8_m100.txt (33333 steps)...
# [Exp8_Transfer_7to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c16_m10.txt (33333 steps)...
# [Exp8_Transfer_7to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c16_m50.txt (33333 steps)...
# [Exp8_Transfer_7to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c16_m100.txt (33333 steps)...
# [Exp8_Transfer_7to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c24_m10.txt (33333 steps)...
# [Exp8_Transfer_7to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c24_m50.txt (33333 steps)...
# [Exp8_Transfer_7to3_finetuned] Training for 33333 steps...
# >>> Training on ft_n7_c24_m100.txt (33333 steps)...
# [Exp8_Transfer_7to3_finetuned] Training for 33333 steps...
#     SKIPPING ft_n7_c24_m100.txt: Expected parameter probs (Tensor of shape (64, 400)) of distribution MaskableCategorical(probs: torch.Size([64, 400]), logits: torch.Size([64, 400])) to satisfy the constraint Simplex(), but found invalid values:
# tensor([[7.9107e-05, 2.4264e-04, 1.3172e-02,  ..., 4.9840e-04, 5.0147e-04,
#          5.0197e-04],
#         [1.6818e-04, 3.5871e-04, 5.1485e-05,  ..., 6.2865e-04, 6.2843e-04,
#          6.2932e-04],
#         [9.0477e-06, 1.7053e-04, 1.4406e-06,  ..., 4.9270e-05, 4.9603e-05,
#          4.9342e-05],
#         ...,
#         [3.9424e-05, 6.5830e-05, 1.2797e-04,  ..., 1.2927e-04, 1.2994e-04,
#          1.2912e-04],
#         [6.5901e-05, 6.0051e-05, 4.4447e-02,  ..., 3.4598e-04, 3.4699e-04,
#          3.4814e-04],
#         [7.9107e-05, 2.4264e-04, 1.3172e-02,  ..., 4.9840e-04, 5.0147e-04,
#          5.0197e-04]], grad_fn=<SoftmaxBackward0>)
#
# >>> Testing Fine-Tuned Model...
#
# --- Starting Testing Phase ---
# Test Strands: [3]
# Testing on test_n3_c8_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m100.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m100.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c24_m10.txt... Score: 100% | Opt: 90% | Gap: 0.0
# Testing on test_n3_c24_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c24_m100.txt... Score: 95% | Opt: 80% | Gap: -0.1
#
# === RESULTS: Exp8_Transfer_7to3_finetuned ===
# Overall Success Rate: 99.44%
# Overall Optimal Rate: 96.67%
# Detailed results saved to ./logs/Exp8_Transfer_7to3_finetuned/results_test.csv
#
# Experiment 8 Complete.
#
# ============================================================
# RUNNING EXPERIMENT 9: Interpolation
# Train Strands: [3, 7] -> Test Strands: [5]
# ============================================================
#
# --- Starting Training Phase (train) ---
# Strands: [3, 7]
# >>> Training on train_n3_c8_m10.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n3_c8_m50.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n3_c8_m100.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n3_c16_m10.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n3_c16_m50.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n3_c16_m100.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n3_c24_m10.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n3_c24_m50.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n3_c24_m100.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n7_c8_m10.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n7_c8_m50.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n7_c8_m100.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n7_c16_m10.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n7_c16_m50.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n7_c16_m100.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n7_c24_m10.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n7_c24_m50.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
# >>> Training on train_n7_c24_m100.txt (16666 steps)...
# [Exp9_Interpolation_pretrained] Training for 16666 steps...
#
# >>> Testing Pre-Trained Model...
#
# --- Starting Testing Phase ---
# Test Strands: [5]
# Testing on test_n5_c8_m10.txt... Score: 90% | Opt: 85% | Gap: 0.1
# Testing on test_n5_c8_m50.txt... Score: 75% | Opt: 50% | Gap: -0.1
# Testing on test_n5_c8_m100.txt... Score: 65% | Opt: 45% | Gap: 0.6
# Testing on test_n5_c16_m10.txt... Score: 45% | Opt: 25% | Gap: -0.2
# Testing on test_n5_c16_m50.txt... Score: 40% | Opt: 30% | Gap: 0.2
# Testing on test_n5_c16_m100.txt... Score: 55% | Opt: 15% | Gap: -0.7
# Testing on test_n5_c24_m10.txt... Score: 25% | Opt: 20% | Gap: 0.4
# Testing on test_n5_c24_m50.txt... Score: 30% | Opt: 10% | Gap: 0.0
# Testing on test_n5_c24_m100.txt... Score: 10% | Opt: 5% | Gap: 2.0
#
# === RESULTS: Exp9_Interpolation_pretrained ===
# Overall Success Rate: 48.33%
# Overall Optimal Rate: 31.67%
# Detailed results saved to ./logs/Exp9_Interpolation_pretrained/results_test.csv
#
# >>> Switching to Fine-Tuning Mode (New Model Name: Exp9_Interpolation_finetuned)
#
# --- Starting Training Phase (finetune) ---
# Strands: [3, 7]
# >>> Training on ft_n3_c8_m10.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n3_c8_m50.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n3_c8_m100.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n3_c16_m10.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n3_c16_m50.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n3_c16_m100.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n3_c24_m10.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n3_c24_m50.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n3_c24_m100.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n7_c8_m10.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n7_c8_m50.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n7_c8_m100.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n7_c16_m10.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n7_c16_m50.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n7_c16_m100.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n7_c24_m10.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n7_c24_m50.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
# >>> Training on ft_n7_c24_m100.txt (16666 steps)...
# [Exp9_Interpolation_finetuned] Training for 16666 steps...
#
# >>> Testing Fine-Tuned Model...
#
# --- Starting Testing Phase ---
# Test Strands: [5]
# Testing on test_n5_c8_m10.txt... Score: 100% | Opt: 90% | Gap: 0.0
# Testing on test_n5_c8_m50.txt... Score: 100% | Opt: 90% | Gap: 0.0
# Testing on test_n5_c8_m100.txt... Score: 100% | Opt: 70% | Gap: 0.4
# Testing on test_n5_c16_m10.txt... Score: 100% | Opt: 55% | Gap: -0.5
# Testing on test_n5_c16_m50.txt... Score: 100% | Opt: 50% | Gap: -0.1
# Testing on test_n5_c16_m100.txt... Score: 95% | Opt: 35% | Gap: 0.4
# Testing on test_n5_c24_m10.txt... Score: 95% | Opt: 40% | Gap: -0.2
# Testing on test_n5_c24_m50.txt... Score: 100% | Opt: 50% | Gap: 0.7
# Testing on test_n5_c24_m100.txt... Score: 95% | Opt: 30% | Gap: 0.5
#
# === RESULTS: Exp9_Interpolation_finetuned ===
# Overall Success Rate: 98.33%
# Overall Optimal Rate: 56.67%
# Detailed results saved to ./logs/Exp9_Interpolation_finetuned/results_test.csv
#
# Experiment 9 Complete.
#
# ============================================================
# RUNNING EXPERIMENT 10: Generalist
# Train Strands: [3, 5, 7] -> Test Strands: [3, 5, 7]
# ============================================================
#
# --- Starting Training Phase (train) ---
# Strands: [3, 5, 7]
# >>> Training on train_n3_c8_m10.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n3_c8_m50.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n3_c8_m100.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n3_c16_m10.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n3_c16_m50.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n3_c16_m100.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n3_c24_m10.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n3_c24_m50.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n3_c24_m100.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n5_c8_m10.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n5_c8_m50.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n5_c8_m100.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n5_c16_m10.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n5_c16_m50.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n5_c16_m100.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n5_c24_m10.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n5_c24_m50.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n5_c24_m100.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n7_c8_m10.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n7_c8_m50.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n7_c8_m100.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n7_c16_m10.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n7_c16_m50.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n7_c16_m100.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n7_c24_m10.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n7_c24_m50.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
# >>> Training on train_n7_c24_m100.txt (11111 steps)...
# [Exp10_Generalist_pretrained] Training for 11111 steps...
#
# >>> Testing Pre-Trained Model...
#
# --- Starting Testing Phase ---
# Test Strands: [3, 5, 7]
# Testing on test_n3_c8_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m50.txt... Score: 95% | Opt: 95% | Gap: 0.0
# Testing on test_n3_c8_m100.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m10.txt... Score: 90% | Opt: 70% | Gap: 1.4
# Testing on test_n3_c16_m50.txt... Score: 85% | Opt: 75% | Gap: 0.5
# Testing on test_n3_c16_m100.txt... Score: 100% | Opt: 95% | Gap: 0.2
# Testing on test_n3_c24_m10.txt... Score: 75% | Opt: 70% | Gap: 0.1
# Testing on test_n3_c24_m50.txt... Score: 85% | Opt: 65% | Gap: 0.5
# Testing on test_n3_c24_m100.txt... Score: 90% | Opt: 75% | Gap: -0.3
# Testing on test_n5_c8_m10.txt... Score: 80% | Opt: 70% | Gap: -0.2
# Testing on test_n5_c8_m50.txt... Score: 85% | Opt: 75% | Gap: 1.2
# Testing on test_n5_c8_m100.txt... Score: 90% | Opt: 55% | Gap: 1.7
# Testing on test_n5_c16_m10.txt... Score: 55% | Opt: 25% | Gap: 4.2
# Testing on test_n5_c16_m50.txt... Score: 35% | Opt: 15% | Gap: 5.7
# Testing on test_n5_c16_m100.txt... Score: 20% | Opt: 5% | Gap: 2.0
# Testing on test_n5_c24_m10.txt... Score: 35% | Opt: 25% | Gap: -0.6
# Testing on test_n5_c24_m50.txt... Score: 35% | Opt: 5% | Gap: 2.0
# Testing on test_n5_c24_m100.txt... Score: 30% | Opt: 10% | Gap: 0.0
# Testing on test_n7_c8_m10.txt... Score: 85% | Opt: 45% | Gap: 1.4
# Testing on test_n7_c8_m50.txt... Score: 85% | Opt: 40% | Gap: 2.6
# Testing on test_n7_c8_m100.txt... Score: 80% | Opt: 35% | Gap: 1.6
# Testing on test_n7_c16_m10.txt... Score: 35% | Opt: 15% | Gap: 1.1
# Testing on test_n7_c16_m50.txt... Score: 40% | Opt: 10% | Gap: 8.5
# Testing on test_n7_c16_m100.txt... Score: 40% | Opt: 20% | Gap: 3.1
# Testing on test_n7_c24_m10.txt... Score: 30% | Opt: 10% | Gap: 4.0
# Testing on test_n7_c24_m50.txt... Score: 0% | Opt: 0% | Gap: N/A
# Testing on test_n7_c24_m100.txt... Score: 10% | Opt: 0% | Gap: N/A
#
# === RESULTS: Exp10_Generalist_pretrained ===
# Overall Success Rate: 62.59%
# Overall Optimal Rate: 44.63%
# Detailed results saved to ./logs/Exp10_Generalist_pretrained/results_test.csv
#
# >>> Switching to Fine-Tuning Mode (New Model Name: Exp10_Generalist_finetuned)
#
# --- Starting Training Phase (finetune) ---
# Strands: [3, 5, 7]
# >>> Training on ft_n3_c8_m10.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n3_c8_m50.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n3_c8_m100.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n3_c16_m10.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n3_c16_m50.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n3_c16_m100.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n3_c24_m10.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n3_c24_m50.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n3_c24_m100.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n5_c8_m10.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n5_c8_m50.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n5_c8_m100.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n5_c16_m10.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n5_c16_m50.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n5_c16_m100.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n5_c24_m10.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n5_c24_m50.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n5_c24_m100.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n7_c8_m10.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n7_c8_m50.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n7_c8_m100.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n7_c16_m10.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n7_c16_m50.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n7_c16_m100.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n7_c24_m10.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n7_c24_m50.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
# >>> Training on ft_n7_c24_m100.txt (11111 steps)...
# [Exp10_Generalist_finetuned] Training for 11111 steps...
#
# >>> Testing Fine-Tuned Model...
#
# --- Starting Testing Phase ---
# Test Strands: [3, 5, 7]
# Testing on test_n3_c8_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c8_m100.txt... Score: 100% | Opt: 95% | Gap: -0.1
# Testing on test_n3_c16_m10.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c16_m100.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c24_m10.txt... Score: 100% | Opt: 85% | Gap: 0.1
# Testing on test_n3_c24_m50.txt... Score: 100% | Opt: 100% | Gap: 0.0
# Testing on test_n3_c24_m100.txt... Score: 95% | Opt: 80% | Gap: -0.1
# Testing on test_n5_c8_m10.txt... Score: 100% | Opt: 75% | Gap: 0.3
# Testing on test_n5_c8_m50.txt... Score: 100% | Opt: 85% | Gap: -0.1
# Testing on test_n5_c8_m100.txt... Score: 100% | Opt: 85% | Gap: -0.3
# Testing on test_n5_c16_m10.txt... Score: 100% | Opt: 55% | Gap: -0.7
# Testing on test_n5_c16_m50.txt... Score: 100% | Opt: 60% | Gap: 0.2
# Testing on test_n5_c16_m100.txt... Score: 100% | Opt: 45% | Gap: 0.3
# Testing on test_n5_c24_m10.txt... Score: 95% | Opt: 35% | Gap: 0.0
# Testing on test_n5_c24_m50.txt... Score: 100% | Opt: 50% | Gap: -0.1
# Testing on test_n5_c24_m100.txt... Score: 100% | Opt: 60% | Gap: 0.1
# Testing on test_n7_c8_m10.txt... Score: 100% | Opt: 65% | Gap: -0.1
# Testing on test_n7_c8_m50.txt... Score: 100% | Opt: 70% | Gap: 0.3
# Testing on test_n7_c8_m100.txt... Score: 100% | Opt: 40% | Gap: -0.4
# Testing on test_n7_c16_m10.txt... Score: 100% | Opt: 50% | Gap: 0.3
# Testing on test_n7_c16_m50.txt... Score: 100% | Opt: 50% | Gap: 0.5
# Testing on test_n7_c16_m100.txt... Score: 95% | Opt: 30% | Gap: 0.7
# Testing on test_n7_c24_m10.txt... Score: 95% | Opt: 35% | Gap: 0.2
# Testing on test_n7_c24_m50.txt... Score: 90% | Opt: 30% | Gap: 1.8
# Testing on test_n7_c24_m100.txt... Score: 95% | Opt: 10% | Gap: 2.5
#
# === RESULTS: Exp10_Generalist_finetuned ===
# Overall Success Rate: 98.70%
# Overall Optimal Rate: 66.30%
# Detailed results saved to ./logs/Exp10_Generalist_finetuned/results_test.csv
#
# Experiment 10 Complete.
